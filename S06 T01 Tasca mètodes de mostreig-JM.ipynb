# %% [markdown]
# # S06 T01: Sampling methods

# %% [markdown]
# ## Exercises 1 Grab a sports-themed dataset you like. Performs a sampling of the data generating a simple random sample and a systematic sample.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random

pd.set_option('display.float_format', lambda x: '%.0f' % x)

# %%
df = pd.read_csv(r'highest_earning_players.csv', sep=',')

# %% [markdown]
# ### Exploring data

# %%
df
# Out:
#      PlayerId NameFirst   NameLast CurrentHandle CountryCode  TotalUSDPrize  \
# 0        3883     Peter  Rasmussen       dupreeh          dk        1822989
# 1        3679   Andreas   Højsleth         Xyp9x          dk        1799289
# 2        3885   Nicolai     Reedtz        dev1ce          dk        1787490
# 3        3672     Lukas  Rossander        gla1ve          dk        1652351
# 4       17800      Emil       Reif        Magisk          dk        1416449
# ..        ...       ...        ...           ...         ...            ...
# 995      7400     Janne   Mikkonen         Savjz          fi          50734
# 996      3255      Drew  Biessener   Tidesoftime          us          50450
# 997     49164    Simone    Liguori          Leta          it          49300
# 998     43043      Mike    Eichner           Ike          us          48550
# 999      1100   Jeffrey      Brusi          SjoW          se          47974
#
#                                  Game                  Genre
# 0    Counter-Strike: Global Offensive   First-Person Shooter
# 1    Counter-Strike: Global Offensive   First-Person Shooter
# 2    Counter-Strike: Global Offensive   First-Person Shooter
# 3    Counter-Strike: Global Offensive   First-Person Shooter
# 4    Counter-Strike: Global Offensive   First-Person Shooter
# ..                                ...                    ...
# 995                       Hearthstone  Collectible Card Game
# 996                       Hearthstone  Collectible Card Game
# 997                       Hearthstone  Collectible Card Game
# 998                       Hearthstone  Collectible Card Game
# 999                       Hearthstone  Collectible Card Game
#
# [1000 rows x 8 columns]

# %% [markdown]
# The database is about gamming earnings.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PlayerId       1000 non-null   int64
#  1   NameFirst      1000 non-null   object
#  2   NameLast       1000 non-null   object
#  3   CurrentHandle  1000 non-null   object
#  4   CountryCode    1000 non-null   object
#  5   TotalUSDPrize  1000 non-null   float64
#  6   Game           1000 non-null   object
#  7   Genre          1000 non-null   object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %% [markdown]
# There are not Nan

# %%
df[['TotalUSDPrize']].describe()
# Out:
#        TotalUSDPrize
# count           1000
# mean          397793
# std           690849
# min            24172
# 25%            83790
# 50%           168328
# 75%           393735
# max          6952597

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There are not duplicates

# %%
df.groupby('Genre')['TotalUSDPrize'].describe()
# Out:
#                                  count   mean    std   min    25%    50%  \
# Genre
# Battle Royale                      200 279257 377236 47078  83670 159406
# Collectible Card Game              100 133356  91524 47974  69156  97099
# First-Person Shooter               200 344449 340189 53294  89933 258548
# Multiplayer Online Battle Arena    400 585842 993810 24172  72046 184601
# Strategy                           100 253798 199770 81796 109662 162767
#
#                                    75%     max
# Genre
# Battle Royale                   283264 3141395
# Collectible Card Game           162850  491419
# First-Person Shooter            440271 1822989
# Multiplayer Online Battle Arena 609656 6952597
# Strategy                        313492  893337

# %% [markdown]
# The database is quite structurated.

# %%
df.groupby('Game')['TotalUSDPrize'].describe()
# Out:
#                                   count    mean     std    min    25%     50%  \
# Game
# Arena of Valor                      100   83340   84282  24172  38212   58160
# Counter-Strike: Global Offensive    100  565419  357793 232167 304962  443061
# Dota 2                              100 1791788 1388015 591177 819764 1343057
# Fortnite                            100  434094  472427 134800 174660  236438
# Hearthstone                         100  133356   91524  47974  69156   97099
# Heroes of the Storm                 100  117804   84070  50546  65855   89372
# League of Legends                   100  350435  196222 159402 217207  281803
# Overwatch                           100  123478   77250  53294  69685   89436
# PUBG                                100  124420  120127  47078  62519   83191
# Starcraft II                        100  253798  199770  81796 109662  162767
#
#                                      75%     max
# Game
# Arena of Valor                    108895  465686
# Counter-Strike: Global Offensive  740391 1822989
# Dota 2                           2025515 6952597
# Fortnite                          469716 3141395
# Hearthstone                       162850  491419
# Heroes of the Storm               135673  464561
# League of Legends                 461466 1257616
# Overwatch                         159796  331109
# PUBG                              131239  703954
# Starcraft II                      313492  893337

# %% [markdown]
# There is the same number of values per game. It helps to have better samples.

# %%
df.groupby('CountryCode')['TotalUSDPrize'].describe()
# Out:
#              count    mean     std     min     25%     50%     75%     max
# CountryCode
# ar               3  391386  545293   70750   76580   82409  551705 1021000
# at               3  914074  878361  326177  409224  492272 1208023 1923774
# au               5 1599935 2573504   53760   57228   79050 1809225 6000412
# ba               1  762803     NaN  762803  762803  762803  762803  762803
# be               5  246035   71796  172385  179596  249663  287280  341250
# bg               6  956899 1778198   93149  145094  293449  363301 4579118
# br              10  577755  419891   61460  273063  384880 1050430 1063858
# by               2  389815  284903  188358  289086  389815  490543  591271
# ca              37  364423  525256   51637   77433  151117  341250 2257053
# ch               3  292188  118963  176598  231153  285707  349983  414258
# cn             168  430904  607290   24172   65923  128509  546145 2984982
# cu               1   77093     NaN   77093   77093   77093   77093   77093
# cz               3  188208  136109   67097  114557  162018  248763  335508
# de              30  338106  944781   49472   76746  112577  193766 5193383
# dk              36  745578 1225442   47090  165700  328047  791936 6952597
# ee               2 1685007 1667353  506011 1095509 1685007 2274506 2864004
# es               6  148832   87073   58719   75782  133199  227186  252719
# fi              16 1179766 2083443   50734   77546  259607  537204 6470000
# fr              37  427115  896940   54391   91851  229171  422315 5554297
# gb              16  261530  331333   49288   92911  134707  240401 1331128
# gi               1  126205     NaN  126205  126205  126205  126205  126205
# gr               1   94073     NaN   94073   94073   94073   94073   94073
# hk               5  324843  494125   54812   62704   81932  224722 1200043
# hr               2  271737  282197   72193  171965  271737  371509  471280
# ie               1  133114     NaN  133114  133114  133114  133114  133114
# il               2 1232344 1624665   83533  657939 1232344 1806750 2381156
# it               2  173961  176298   49300  111631  173961  236292  298623
# jo               2 3165871 2308240 1533699 2349785 3165871 3981957 4798044
# jp               4  140862   76181   76675   82316  124111  182656  238550
# kr             251  232836  205210   28816   92340  156208  302249 1257616
# kz               6  264500  106701   79672  270929  273822  275018  414306
# lb               1 4193413     NaN 4193413 4193413 4193413 4193413 4193413
# lt               2  117431   31827   94927  106179  117431  128684  139936
# lv               1  269888     NaN  269888  269888  269888  269888  269888
# mk               1 1046690     NaN 1046690 1046690 1046690 1046690 1046690
# mo               1 1337308     NaN 1337308 1337308 1337308 1337308 1337308
# mx               1  377144     NaN  377144  377144  377144  377144  377144
# my               6 1035379  700837   28860  730886  902489 1592314 1882493
# nl              10  391425  377011   64140  119947  217052  570416 1213577
# no              10  425159  431912   67862  213050  276883  365074 1536846
# ph               7  496434  290175  131989  227016  609393  740514  798597
# pk               1 3608317     NaN 3608317 3608317 3608317 3608317 3608317
# pl              14  418932  244189   87636  236767  387523  587979  933854
# ro               2 1239838 1464825  204050  721944 1239838 1757732 2275626
# ru              22  491950  587579   58459  109035  233453  485606 1787797
# se              45  461565  524388   47974  160819  284845  638939 2545626
# sg               1 1553262     NaN 1553262 1553262 1553262 1553262 1553262
# si               4  166025   63821   75979  144768  183914  205171  220292
# sk               3  456436  296946  265131  285393  305655  552088  798521
# th              29   63655   30936   25941   45996   54156   74492  135750
# tr               4  212759  110356   85244  138145  229331  303946  307130
# tw              34  129393  123655   26645   42482   92985  170248  538926
# ua              12  681001  483044  121248  257845  669213  830799 1617323
# us             114  378065  578914   34191   81326  170087  387581 3141395
# uz               1  232167     NaN  232167  232167  232167  232167  232167
# vn               7  111112   45480   34812   90793  131670  138489  152735

# %% [markdown]
# There are more players from China and Korea.

# %% [markdown]
# ###  Simple random sample

# %%
sample_df = df.sample(100)
sample_df
# Out:
#      PlayerId    NameFirst            NameLast CurrentHandle CountryCode  \
# 812     37261  Sorawichaya         Mahavanakul    Isilindilz          th
# 534     11418      Mikołaj           Ogonowski        Elazer          pl
# 396     62624       Moussa               Faour        Chapix          se
# 957     45830       Wataru           Ishibashi        posesi          jp
# 175     30452         Peng                  Du         Monet          cn
# ..        ...          ...                 ...           ...         ...
# 972     15703         Facu              Pruzzo     Nalguidan          ar
# 852     60456     Sorachat  Janechaijitravanit       Getsrch          th
# 931     28238          Lin               Zheng     OmegaZero          cn
# 854     36696        Kawee         Wachiraphas       MeMarkz          th
# 336     65116            -                   -          Zand          dk
#
#      TotalUSDPrize            Game                            Genre
# 812         131426  Arena of Valor  Multiplayer Online Battle Arena
# 534         264095    Starcraft II                         Strategy
# 396         136820        Fortnite                    Battle Royale
# 957          84196     Hearthstone            Collectible Card Game
# 175         813170          Dota 2  Multiplayer Online Battle Arena
# ..             ...             ...                              ...
# 972          70750     Hearthstone            Collectible Card Game
# 852          57379  Arena of Valor  Multiplayer Online Battle Arena
# 931         139426     Hearthstone            Collectible Card Game
# 854          55686  Arena of Valor  Multiplayer Online Battle Arena
# 336         341250        Fortnite                    Battle Royale
#
# [100 rows x 8 columns]

# %%
sample_df[['TotalUSDPrize']].describe()
# Out:
#        TotalUSDPrize
# count            100
# mean          472153
# std           914720
# min            26696
# 25%            77441
# 50%           153191
# 75%           342375
# max          6470000

# %% [markdown]
# The median of prices in dollars is similar: 168,328 dollars in the whole database and 164,980 in the simple random sample.

# %% [markdown]
# ###  Systematic random sample

# %%
# Choosing Random Number
random_number = random.randint(1, 10)

# %%
# Define systematic sampling function

def systematic_sampling(df, step):
 
    indexes = np.arange(random_number, len(df), step=step)
    systematic_sample = df.iloc[indexes]
    return systematic_sample
 
 
systematic_sample = systematic_sampling(df, 10 )
 

display(systematic_sample)
# Out:
#      PlayerId NameFirst      NameLast CurrentHandle CountryCode  \
# 4       17800      Emil          Reif        Magisk          dk
# 14       3875    Jesper      Wecksell            JW          se
# 24       5783    Nikola         Kovač          NiKo          ba
# 34       3951     Chris       de Jong        chrisJ          nl
# 44       3293    Cédric       Guipouy           RpK          fr
# ..        ...       ...           ...           ...         ...
# 954     37063   Tsu Lin          Tsao    SamuelTsao          tw
# 964     39850     Tyler  Hoang Nguyen     Tylerootd          nl
# 974     17263      Chen       Yuxiang        Breath          cn
# 984     12793   Jeffrey           Liu         Tarei          us
# 994      8321     Petar    Stevanovic         Gaara          de
#
#      TotalUSDPrize                              Game                  Genre
# 4          1416449  Counter-Strike: Global Offensive   First-Person Shooter
# 14          897761  Counter-Strike: Global Offensive   First-Person Shooter
# 24          762803  Counter-Strike: Global Offensive   First-Person Shooter
# 34          596749  Counter-Strike: Global Offensive   First-Person Shooter
# 44          498888  Counter-Strike: Global Offensive   First-Person Shooter
# ..             ...                               ...                    ...
# 954          89250                       Hearthstone  Collectible Card Game
# 964          78375                       Hearthstone  Collectible Card Game
# 974          69488                       Hearthstone  Collectible Card Game
# 984          62454                       Hearthstone  Collectible Card Game
# 994          51060                       Hearthstone  Collectible Card Game
#
# [100 rows x 8 columns]

# %%
systematic_sample[['TotalUSDPrize']].describe()
# Out:
#        TotalUSDPrize
# count            100
# mean          400329
# std           693380
# min            26667
# 25%            85339
# 50%           170430
# 75%           365042
# max          5470903

# %% [markdown]
# The median of dollar prices in the systematic sample is higher, 178,252 dollars, than in the whole database (168,328 dollars) and the simple random sample (164,980 dollars).

# %% [markdown]
# ## Exercise 2 Estratified sample and sample using SMOTE (Synthetic Minority Oversampling Technique).

# %% [markdown]
# ### Estratified sample

# %%
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest, f_classif

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# I try two ways to estratifie using train_test_split, which split arrays or matrices into random train and test subsets.

# %%
# Use directly the function and let Sklearn to do the rest
strat1=train_test_split(df, df[['CountryCode','TotalUSDPrize','Game','Genre']])
strat1
# Out:
# [     PlayerId   NameFirst  NameLast CurrentHandle CountryCode  TotalUSDPrize  \
#  201      6466    Ho Seong       Lee          Duke          kr         954621
#  13       8635        Nick  Cannella         nitr0          us         920152
#  166      3522       Jacky       Mao   EternaLEnVy          ca         987073
#  729     45412  Young Hoon      Shim         Simsn          kr         125722
#  150      2598     Fa Ming     Liang           DDC          mo        1337308
#  ..        ...         ...       ...           ...         ...            ...
#  115      2578     Clement    Ivanov        Puppey          ee        2864004
#  901     11132     Wei Lin      Chen      tom60229          tw         442878
#  142      3161      Junhao       Xie         Super          cn        1598492
#  794     48874     Michael      Wake         mykLe          gb          49288
#  44       3293      Cédric   Guipouy           RpK          fr         498888
#
#                                   Game                            Genre
#  201                 League of Legends  Multiplayer Online Battle Arena
#  13   Counter-Strike: Global Offensive             First-Person Shooter
#  166                            Dota 2  Multiplayer Online Battle Arena
#  729                              PUBG                    Battle Royale
#  150                            Dota 2  Multiplayer Online Battle Arena
#  ..                                ...                              ...
#  115                            Dota 2  Multiplayer Online Battle Arena
#  901                       Hearthstone            Collectible Card Game
#  142                            Dota 2  Multiplayer Online Battle Arena
#  794                              PUBG                    Battle Royale
#  44   Counter-Strike: Global Offensive             First-Person Shooter
#
#  [750 rows x 8 columns],
#       PlayerId   NameFirst NameLast CurrentHandle CountryCode  TotalUSDPrize  \
#  607     15602      Joshua  Bennett        Snitch          gb         238799
#  390     65470           -        -       Furious          us         143908
#  980     49179      Martin    Prête          Zhym          fr          65702
#  895     83084  Tseng-Yung     Chun          Kato          tw          26667
#  175     30452        Peng       Du         Monet          cn         813170
#  ..        ...         ...      ...           ...         ...            ...
#  866     78046           -        -          Mojo          cn          43265
#  138      3146      Zhihao     Chen           Hao          cn        1755206
#  796     45682           -        -         Makne          kr          48503
#  425     42667   Tae-seong    Jeong         ANAMO          kr         159757
#  123     10712       Zhang   Yiping            y`          cn        2097095
#
#                      Game                            Genre
#  607  Heroes of the Storm  Multiplayer Online Battle Arena
#  390             Fortnite                    Battle Royale
#  980          Hearthstone            Collectible Card Game
#  895       Arena of Valor  Multiplayer Online Battle Arena
#  175               Dota 2  Multiplayer Online Battle Arena
#  ..                   ...                              ...
#  866       Arena of Valor  Multiplayer Online Battle Arena
#  138               Dota 2  Multiplayer Online Battle Arena
#  796                 PUBG                    Battle Royale
#  425            Overwatch             First-Person Shooter
#  123               Dota 2  Multiplayer Online Battle Arena
#
#  [250 rows x 8 columns],
#      CountryCode  TotalUSDPrize                              Game  \
#  201          kr         954621                 League of Legends
#  13           us         920152  Counter-Strike: Global Offensive
#  166          ca         987073                            Dota 2
#  729          kr         125722                              PUBG
#  150          mo        1337308                            Dota 2
#  ..          ...            ...                               ...
#  115          ee        2864004                            Dota 2
#  901          tw         442878                       Hearthstone
#  142          cn        1598492                            Dota 2
#  794          gb          49288                              PUBG
#  44           fr         498888  Counter-Strike: Global Offensive
#
#                                 Genre
#  201  Multiplayer Online Battle Arena
#  13              First-Person Shooter
#  166  Multiplayer Online Battle Arena
#  729                    Battle Royale
#  150  Multiplayer Online Battle Arena
#  ..                               ...
#  115  Multiplayer Online Battle Arena
#  901            Collectible Card Game
#  142  Multiplayer Online Battle Arena
#  794                    Battle Royale
#  44              First-Person Shooter
#
#  [750 rows x 4 columns],
#      CountryCode  TotalUSDPrize                 Game  \
#  607          gb         238799  Heroes of the Storm
#  390          us         143908             Fortnite
#  980          fr          65702          Hearthstone
#  895          tw          26667       Arena of Valor
#  175          cn         813170               Dota 2
#  ..          ...            ...                  ...
#  866          cn          43265       Arena of Valor
#  138          cn        1755206               Dota 2
#  796          kr          48503                 PUBG
#  425          kr         159757            Overwatch
#  123          cn        2097095               Dota 2
#
#                                 Genre
#  607  Multiplayer Online Battle Arena
#  390                    Battle Royale
#  980            Collectible Card Game
#  895  Multiplayer Online Battle Arena
#  175  Multiplayer Online Battle Arena
#  ..                               ...
#  866  Multiplayer Online Battle Arena
#  138  Multiplayer Online Battle Arena
#  796                    Battle Royale
#  425             First-Person Shooter
#  123  Multiplayer Online Battle Arena
#
#  [250 rows x 4 columns]]

# %%
# Introduce more parameters
X = df
y=df[['CurrentHandle','CountryCode','TotalUSDPrize','Game','Genre']]

# %%
X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(X, y, train_size=0.8,test_size=0.20, random_state=100)
print ("X_train: ", X_train)
print ("y_train: ", y_train)
print("X_test: ", X_test)
print ("y_test: ", y_test)
# Out:
# X_train:       PlayerId    NameFirst     NameLast CurrentHandle CountryCode  \
# 675     22244       Markus        Hanke        Blumbi          de
# 358     51909       Patrik  Zaharchenko        Pate1k          no
# 159      3164   Zhengzheng          Yao           Yao          cn
# 533      1030      Ji Sung         Choi        Bomber          kr
# 678     21719      Michael        Udall  MichaelUdall          us
# ..        ...          ...          ...           ...         ...
# 855     18456      Pakinai    Srivijarn          kSsA          th
# 871     53974            -            -       Sirenia          tw
# 835     70308            -            -            轻雨          cn
# 792     48935       Magnus     Hartmann         udyRR          de
# 520      1175  Juan Carlos        Lopez       SpeCial          mx
#
#      TotalUSDPrize                 Game                            Genre
# 675          65526  Heroes of the Storm  Multiplayer Online Battle Arena
# 358         207201             Fortnite                    Battle Royale
# 159        1186003               Dota 2  Multiplayer Online Battle Arena
# 533         265915         Starcraft II                         Strategy
# 678          64763  Heroes of the Storm  Multiplayer Online Battle Arena
# ..             ...                  ...                              ...
# 855          54159       Arena of Valor  Multiplayer Online Battle Arena
# 871          42482       Arena of Valor  Multiplayer Online Battle Arena
# 835          65923       Arena of Valor  Multiplayer Online Battle Arena
# 792          49761                 PUBG                    Battle Royale
# 520         377144         Starcraft II                         Strategy
#
# [800 rows x 8 columns]
# y_train:      CurrentHandle CountryCode  TotalUSDPrize                 Game  \
# 675        Blumbi          de          65526  Heroes of the Storm
# 358        Pate1k          no         207201             Fortnite
# 159           Yao          cn        1186003               Dota 2
# 533        Bomber          kr         265915         Starcraft II
# 678  MichaelUdall          us          64763  Heroes of the Storm
# ..            ...         ...            ...                  ...
# 855          kSsA          th          54159       Arena of Valor
# 871       Sirenia          tw          42482       Arena of Valor
# 835            轻雨          cn          65923       Arena of Valor
# 792         udyRR          de          49761                 PUBG
# 520       SpeCial          mx         377144         Starcraft II
#
#                                Genre
# 675  Multiplayer Online Battle Arena
# 358                    Battle Royale
# 159  Multiplayer Online Battle Arena
# 533                         Strategy
# 678  Multiplayer Online Battle Arena
# ..                               ...
# 855  Multiplayer Online Battle Arena
# 871  Multiplayer Online Battle Arena
# 835  Multiplayer Online Battle Arena
# 792                    Battle Royale
# 520                         Strategy
#
# [800 rows x 5 columns]
# X_test:       PlayerId   NameFirst  NameLast CurrentHandle CountryCode  TotalUSDPrize  \
# 249      3769     Zachary   Scuderi        Sneaky          us         282456
# 353     61277        Josh     Roach   Commandment          us         221752
# 537      3041   Yoon Jong      Jung          Rain          kr         236691
# 424     50329  Seon Chang       Lee           ANS          kr         159912
# 564      1024   Hoon Jung        Ji        Jjakji          kr         133917
# ..        ...         ...       ...           ...         ...            ...
# 684     21427      Zhihao     Zhang           zZH          cn          60952
# 644     15750   Alexander   Milanov      ethernal          bg          93149
# 110     14196      Sumail    Hassan        SumaiL          pk        3608317
# 28       8169   Alexander  Kostylev        s1mple          ua         677155
# 804     70611        Cong     Zhang        Wuming          cn         399019
#
#                                  Game                            Genre
# 249                 League of Legends  Multiplayer Online Battle Arena
# 353                          Fortnite                    Battle Royale
# 537                      Starcraft II                         Strategy
# 424                         Overwatch             First-Person Shooter
# 564                      Starcraft II                         Strategy
# ..                                ...                              ...
# 684               Heroes of the Storm  Multiplayer Online Battle Arena
# 644               Heroes of the Storm  Multiplayer Online Battle Arena
# 110                            Dota 2  Multiplayer Online Battle Arena
# 28   Counter-Strike: Global Offensive             First-Person Shooter
# 804                    Arena of Valor  Multiplayer Online Battle Arena
#
# [200 rows x 8 columns]
# y_test:      CurrentHandle CountryCode  TotalUSDPrize  \
# 249        Sneaky          us         282456
# 353   Commandment          us         221752
# 537          Rain          kr         236691
# 424           ANS          kr         159912
# 564        Jjakji          kr         133917
# ..            ...         ...            ...
# 684           zZH          cn          60952
# 644      ethernal          bg          93149
# 110        SumaiL          pk        3608317
# 28         s1mple          ua         677155
# 804        Wuming          cn         399019
#
#                                  Game                            Genre
# 249                 League of Legends  Multiplayer Online Battle Arena
# 353                          Fortnite                    Battle Royale
# 537                      Starcraft II                         Strategy
# 424                         Overwatch             First-Person Shooter
# 564                      Starcraft II                         Strategy
# ..                                ...                              ...
# 684               Heroes of the Storm  Multiplayer Online Battle Arena
# 644               Heroes of the Storm  Multiplayer Online Battle Arena
# 110                            Dota 2  Multiplayer Online Battle Arena
# 28   Counter-Strike: Global Offensive             First-Person Shooter
# 804                    Arena of Valor  Multiplayer Online Battle Arena
#
# [200 rows x 5 columns]

# %%
X_test[['TotalUSDPrize']].describe()
# Out:
#        TotalUSDPrize
# count            200
# mean          491010
# std           825077
# min            25941
# 25%            90364
# 50%           182583
# 75%           519378
# max          6470000

# %% [markdown]
# The median of dollar prices in the stratified sample is 182.583 dollars, higher than in the systematic sample (178,252 dollars), the whole database (168,328 dollars) or the simple random sample (164,980).

# %% [markdown]
# ### SMOTE (Synthetic Minority Oversampling Technique).

# %% [markdown]
# Synthetic Minority Oversampling Technique is an Oversampling technique that allows us to generate synthetic samples for our minority categories.So, we get a difference between a sample and one of its k nearest neighbours and multiply by some random value in the range of (0, 1). A problem with imbalanced classification is that there are too few examples of the minority class for a model to effectively learn the decision boundary.

# %%
from imblearn.over_sampling import SMOTE
from sklearn import preprocessing

# %%
df2= df.loc[:, ['CountryCode','TotalUSDPrize','Game','Genre']]
df2
# Out:
#     CountryCode  TotalUSDPrize                              Game  \
# 0            dk        1822989  Counter-Strike: Global Offensive
# 1            dk        1799289  Counter-Strike: Global Offensive
# 2            dk        1787490  Counter-Strike: Global Offensive
# 3            dk        1652351  Counter-Strike: Global Offensive
# 4            dk        1416449  Counter-Strike: Global Offensive
# ..          ...            ...                               ...
# 995          fi          50734                       Hearthstone
# 996          us          50450                       Hearthstone
# 997          it          49300                       Hearthstone
# 998          us          48550                       Hearthstone
# 999          se          47974                       Hearthstone
#
#                      Genre
# 0     First-Person Shooter
# 1     First-Person Shooter
# 2     First-Person Shooter
# 3     First-Person Shooter
# 4     First-Person Shooter
# ..                     ...
# 995  Collectible Card Game
# 996  Collectible Card Game
# 997  Collectible Card Game
# 998  Collectible Card Game
# 999  Collectible Card Game
#
# [1000 rows x 4 columns]

# %%
# Creating instance of labelencoder
labelencoder = preprocessing.LabelEncoder()
# Assigning numerical values and storing in another column

df2['CountryCode_num'] = labelencoder.fit_transform(df2['CountryCode'])
df2['Game_num']= labelencoder.fit_transform(df2['Game'])

# %%
df2
# Out:
#     CountryCode  TotalUSDPrize                              Game  \
# 0            dk        1822989  Counter-Strike: Global Offensive
# 1            dk        1799289  Counter-Strike: Global Offensive
# 2            dk        1787490  Counter-Strike: Global Offensive
# 3            dk        1652351  Counter-Strike: Global Offensive
# 4            dk        1416449  Counter-Strike: Global Offensive
# ..          ...            ...                               ...
# 995          fi          50734                       Hearthstone
# 996          us          50450                       Hearthstone
# 997          it          49300                       Hearthstone
# 998          us          48550                       Hearthstone
# 999          se          47974                       Hearthstone
#
#                      Genre  CountryCode_num  Game_num
# 0     First-Person Shooter               14         1
# 1     First-Person Shooter               14         1
# 2     First-Person Shooter               14         1
# 3     First-Person Shooter               14         1
# 4     First-Person Shooter               14         1
# ..                     ...              ...       ...
# 995  Collectible Card Game               17         4
# 996  Collectible Card Game               53         4
# 997  Collectible Card Game               26         4
# 998  Collectible Card Game               53         4
# 999  Collectible Card Game               45         4
#
# [1000 rows x 6 columns]

# %%
X=df2[['TotalUSDPrize','CountryCode_num', 'Game_num']]
X
# Out:
#      TotalUSDPrize  CountryCode_num  Game_num
# 0          1822989               14         1
# 1          1799289               14         1
# 2          1787490               14         1
# 3          1652351               14         1
# 4          1416449               14         1
# ..             ...              ...       ...
# 995          50734               17         4
# 996          50450               53         4
# 997          49300               26         4
# 998          48550               53         4
# 999          47974               45         4
#
# [1000 rows x 3 columns]

# %%
y=df2['Genre']

# %%
seed=100
k=1
sm= SMOTE(sampling_strategy='auto', k_neighbors=k, random_state=seed)
X_res, y_res = sm.fit_resample(X, y)

# %%
X_res
# Out:
#       TotalUSDPrize  CountryCode_num  Game_num
# 0           1822989               14         1
# 1           1799289               14         1
# 2           1787490               14         1
# 3           1652351               14         1
# 4           1416449               14         1
# ...             ...              ...       ...
# 1995         518525               43         9
# 1996         132990               16         9
# 1997         884038               29         9
# 1998          93877               29         9
# 1999         108361               29         9
#
# [2000 rows x 3 columns]

# %%
y_res
# Out:
# 0       First-Person Shooter
# 1       First-Person Shooter
# 2       First-Person Shooter
# 3       First-Person Shooter
# 4       First-Person Shooter
#                 ...
# 1995                Strategy
# 1996                Strategy
# 1997                Strategy
# 1998                Strategy
# 1999                Strategy
# Name: Genre, Length: 2000, dtype: object

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   TotalUSDPrize    2000 non-null   float64
#  1   CountryCode_num  2000 non-null   int64
#  2   Game_num         2000 non-null   int64
#  3   Genre            2000 non-null   object
# dtypes: float64(1), int64(2), object(1)
# memory usage: 62.6+ KB

# %%
df3.Game_num. value_counts()
# Out:
# 4    408
# 9    400
# 7    205
# 1    196
# 3    185
# 8    183
# 5    114
# 6    108
# 2    101
# 0    100
# Name: Game_num, dtype: int64

# %%
df3.Genre. value_counts()
# Out:
# Strategy                           400
# Multiplayer Online Battle Arena    400
# First-Person Shooter               400
# Collectible Card Game              400
# Battle Royale                      400
# Name: Genre, dtype: int64

# %%
df.Genre. value_counts()
# Out:
# Multiplayer Online Battle Arena    400
# Battle Royale                      200
# First-Person Shooter               200
# Collectible Card Game              100
# Strategy                           100
# Name: Genre, dtype: int64

# %%
X_res[['TotalUSDPrize']].describe()
# Out:
#        TotalUSDPrize
# count           2000
# mean          321146
# std           535898
# min            24172
# 25%            85541
# 50%           152769
# 75%           327898
# max          6952597

# %% [markdown]
# Though our database is balanced we have applied SOME sampling as an exercise. With SMOTE sample the median is lower, 152.769 dollars, but we have used "Genre" as y. Anyway, in this dataset there was not a problem of oversampling or undersampling.

# %% [markdown]
# ## Exercise 3 Reservoir sampling.

# %% [markdown]
# Weighted random sampling with a reservoir; Pavlos S.Efraimidis; Paul G. Spirakis (2006). Applies when we have a stream of items of large and unknown length that we can only iterate over once. Creates an algorithm that randomly chooses an item from this stream such that each item is equally likely to be selected. I use the same dataset to show an exemple.

# %%
from random import uniform
from random import randint

import numpy as np
import matplotlib.pyplot as plt

# %%
# Doing Reservoir Sampling from the stream
k=100
reservoir = []
for i, element in enumerate(df["TotalUSDPrize"]):
    if i+1<= k:
        reservoir.append(element)
    else:
        probability = k/(i+1)
        if random.random() < probability:
            # Select item in stream and remove one of the k items already selected
             reservoir[random.choice(range(0,k))] = element
print(reservoir)
# Out:
# [243027.72, 1799288.57, 83373.91, 28083.35, 1416448.64, 1755205.74, 1063858.27, 89346.12, 232418.28, 88443.76, 170911.34, 127688.41, 65922.73, 166127.4, 2002159.51, 133715.0, 188358.03, 867823.34, 327424.24, 180858.29, 805444.66, 250580.01, 47602.61, 87834.52, 66306.23, 1349767.32, 64304.93, 689568.7, 82409.24, 81023.44, 119560.82, 69918.09, 53293.7, 162017.51, 81795.94, 136120.04, 762437.0, 2551657.34, 2275625.58, 1257615.87, 289675.08, 326176.94, 106225.0, 31489.38, 2864004.17, 191647.23, 112482.56, 28816.0, 483747.81, 227008.15, 437479.98, 152619.67, 297730.97, 414305.65, 68984.11, 89669.63, 132306.1, 104671.25, 70298.68, 78178.8, 126204.51, 58160.23, 361678.02, 174361.72, 135189.54, 114751.8, 315616.67, 111710.36, 1213576.66, 102114.43, 88040.91, 341250.0, 156959.11, 133558.02, 89725.4, 164363.81, 265429.15, 41144.36, 1598492.49, 810683.0, 148558.05, 325910.24, 594850.0, 227550.0, 545447.56, 165348.34, 1873138.8, 152734.63, 271901.75, 133114.01, 171767.15, 1186002.61, 75756.09, 51048.44, 182877.42, 285707.09, 31489.38, 234332.17, 163336.4, 72637.5]

# %%
df4=df[df.TotalUSDPrize.isin(reservoir)]
df4
# Out:
#      PlayerId  NameFirst   NameLast CurrentHandle CountryCode  TotalUSDPrize  \
# 1        3679    Andreas   Højsleth         Xyp9x          dk        1799289
# 4       17800       Emil       Reif        Magisk          dk        1416449
# 6       12183   Epitácio    de Melo          TACO          br        1063858
# 17       5000     Freddy  Johansson         KRiMZ          se         867823
# 20       3290     Nathan    Schmitt           NBK          fr         805445
# ..        ...        ...        ...           ...         ...            ...
# 934     33382   Cheon Su        Kim       Che0nsu          kr         133715
# 953     43794      Juwei         Wu         XiaoT          cn          89346
# 958     47728    Zakarya       Hail       xBlyzes          fr          83374
# 959     30167  Francisco  Leimontas           PNC          ar          82409
# 971      7139    Jeffrey       Shih         Trump          us          72638
#
#                                  Game                  Genre
# 1    Counter-Strike: Global Offensive   First-Person Shooter
# 4    Counter-Strike: Global Offensive   First-Person Shooter
# 6    Counter-Strike: Global Offensive   First-Person Shooter
# 17   Counter-Strike: Global Offensive   First-Person Shooter
# 20   Counter-Strike: Global Offensive   First-Person Shooter
# ..                                ...                    ...
# 934                       Hearthstone  Collectible Card Game
# 953                       Hearthstone  Collectible Card Game
# 958                       Hearthstone  Collectible Card Game
# 959                       Hearthstone  Collectible Card Game
# 971                       Hearthstone  Collectible Card Game
#
# [119 rows x 8 columns]

# %%
df4[['TotalUSDPrize']].describe()
# Out:
#        TotalUSDPrize
# count            119
# mean          369019
# std           556024
# min            28083
# 25%            74197
# 50%           148558
# 75%           326044
# max          2864004

# %% [markdown]
# With this sample method the median is 125.459 dollars.
